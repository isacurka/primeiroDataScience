# %% [markdown]
# <a href="https://colab.research.google.com/github/isacurka/primeiroDataScience/blob/main/Notebooks/dados_da_covid_RS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Trazendo os arquivos necessarios para analise

# %%
import pandas as pd

dados=pd.read_csv("dados_covid.csv",sep=";")
dados
# Out:
#          COD_IBGE  MUNICIPIO  ...  PAIS_NASCIMENTO PES_PRIV_LIBERDADE
# 0          430003     ACEGUÁ  ...           BRASIL                NAO
# 1          430003     ACEGUÁ  ...           BRASIL                NAO
# 2          430003     ACEGUÁ  ...           BRASIL                NAO
# 3          430003     ACEGUÁ  ...           BRASIL                NAO
# 4          430003     ACEGUÁ  ...           BRASIL                NAO
# ...           ...        ...  ...              ...                ...
# 1276141    431990  SAPIRANGA  ...           BRASIL                NAO
# 1276142    431990  SAPIRANGA  ...           BRASIL                NAO
# 1276143    431990  SAPIRANGA  ...           BRASIL                NAO
# 1276144    431990  SAPIRANGA  ...           BRASIL                NAO
# 1276145    431990  SAPIRANGA  ...              NaN                NaN
#
# [1276146 rows x 30 columns]

# %%
df=pd.DataFrame(dados)

# %%
df[["FAIXAETARIA","DATA_EVOLUCAO"]].describe()
# Out:
#        FAIXAETARIA DATA_EVOLUCAO
# count      1276146         90278
# unique          12           566
# top        30 a 39    18/03/2021
# freq        276017           668

# %%
df.info
# Out:
# <bound method DataFrame.info of          COD_IBGE  MUNICIPIO  ...  PAIS_NASCIMENTO PES_PRIV_LIBERDADE
# 0          430003     ACEGUÁ  ...           BRASIL                NAO
# 1          430003     ACEGUÁ  ...           BRASIL                NAO
# 2          430003     ACEGUÁ  ...           BRASIL                NAO
# 3          430003     ACEGUÁ  ...           BRASIL                NAO
# 4          430003     ACEGUÁ  ...           BRASIL                NAO
# ...           ...        ...  ...              ...                ...
# 1276141    431990  SAPIRANGA  ...           BRASIL                NAO
# 1276142    431990  SAPIRANGA  ...           BRASIL                NAO
# 1276143    431990  SAPIRANGA  ...           BRASIL                NAO
# 1276144    431990  SAPIRANGA  ...           BRASIL                NAO
# 1276145    431990  SAPIRANGA  ...              NaN                NaN
#
# [1276146 rows x 30 columns]>

# %%
df.dtypes
# Out:
# COD_IBGE                   int64
# MUNICIPIO                 object
# COD_REGIAO_COVID           int64
# REGIAO_COVID              object
# SEXO                      object
# FAIXAETARIA               object
# CRITERIO                  object
# DATA_CONFIRMACAO          object
# DATA_SINTOMAS             object
# DATA_INCLUSAO             object
# DATA_EVOLUCAO             object
# EVOLUCAO                  object
# HOSPITALIZADO             object
# FEBRE                     object
# TOSSE                     object
# GARGANTA                  object
# DISPNEIA                  object
# OUTROS                    object
# CONDICOES                 object
# GESTANTE                  object
# DATA_INCLUSAO_OBITO       object
# DATA_EVOLUCAO_ESTIMADA    object
# RACA_COR                  object
# ETNIA_INDIGENA            object
# PROFISSIONAL_SAUDE        object
# BAIRRO                    object
# SRAG                      object
# FONTE_INFORMACAO          object
# ...

# %%
df[["MUNICIPIO"]]
# Out:
#          MUNICIPIO
# 0           ACEGUÁ
# 1           ACEGUÁ
# 2           ACEGUÁ
# 3           ACEGUÁ
# 4           ACEGUÁ
# ...            ...
# 1276141  SAPIRANGA
# 1276142  SAPIRANGA
# 1276143  SAPIRANGA
# 1276144  SAPIRANGA
# 1276145  SAPIRANGA
#
# [1276146 rows x 1 columns]

# %%
df2=df.set_index("MUNICIPIO")

# %%
df2.loc['PELOTAS']
# Out:
#            COD_IBGE  COD_REGIAO_COVID  ... PAIS_NASCIMENTO PES_PRIV_LIBERDADE
# MUNICIPIO                              ...
# PELOTAS      431440                15  ...          BRASIL                NAO
# PELOTAS      431440                15  ...          BRASIL                NAO
# PELOTAS      431440                15  ...          BRASIL                NAO
# PELOTAS      431440                15  ...          BRASIL                NAO
# PELOTAS      431440                15  ...          BRASIL                NAO
# ...             ...               ...  ...             ...                ...
# PELOTAS      431440                15  ...          BRASIL                NAO
# PELOTAS      431440                15  ...          BRASIL                NAO
# PELOTAS      431440                15  ...          BRASIL                NAO
# PELOTAS      431440                15  ...          BRASIL                NAO
# ...

# %%
df2.loc["PELOTAS"].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46243 entries, PELOTAS to PELOTAS
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   COD_IBGE                46243 non-null  int64
#  1   COD_REGIAO_COVID        46243 non-null  int64
#  2   REGIAO_COVID            46243 non-null  object
#  3   SEXO                    46243 non-null  object
#  4   FAIXAETARIA             46243 non-null  object
#  5   CRITERIO                46243 non-null  object
#  6   DATA_CONFIRMACAO        46243 non-null  object
#  7   DATA_SINTOMAS           46243 non-null  object
#  8   DATA_INCLUSAO           46243 non-null  object
#  9   DATA_EVOLUCAO           2603 non-null   object
#  10  EVOLUCAO                46243 non-null  object
#  11  HOSPITALIZADO           46243 non-null  object
#  12  FEBRE                   46241 non-null  object
#  13  TOSSE                   46241 non-null  object
# ...

# %%
}
